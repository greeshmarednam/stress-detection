# %%
import os
import cv2
import numpy as np
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix 
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import tensorflow as tf
from tensorflow.keras import layers, models

# %%
DATA_DIR = 'images/'
EMOTIONS = ['Anger', 'Contempt', 'Disgust', 'Fear', 'Happy', 'Neutral', 'Sad', 'Surprised']
IMG_SIZE = 48

# %%
def load_data():
    images = []
    labels = []
    
    for emotion_label, emotion in enumerate(EMOTIONS):
        emotion_dir = os.path.join(DATA_DIR, str(emotion_label))
        if os.path.isdir(emotion_dir):
            for img_file in os.listdir(emotion_dir):
                img_path = os.path.join(emotion_dir, img_file)
                img_array = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)
                img_resized = cv2.resize(img_array, (IMG_SIZE, IMG_SIZE))
                images.append(img_resized)
                labels.append(emotion_label)
        else:
            print(f"Directory not found for emotion {emotion}: {emotion_dir}")
        
    return np.array(images), np.array(labels)

# Load the data
images, labels = load_data()


# Split data into train and test sets
X_train, X_test, y_train, y_test = train_test_split(images, labels, test_size=0.2, random_state=42)

# Normalize the pixel values
X_train = X_train / 255.0
X_test = X_test / 255.0

# Reshape data for CNN input
X_train = X_train.reshape(-1, IMG_SIZE, IMG_SIZE, 1)
X_test = X_test.reshape(-1, IMG_SIZE, IMG_SIZE, 1)

# %%
# Print information about the dataset
print("Number of images:", len(images))
print("Shape of images array:", images.shape)
print("Number of labels:", len(labels))

# Print sample images and their corresponding labels
import matplotlib.pyplot as plt

plt.figure(figsize=(20, 20))
for i in range(25):
    plt.subplot(5, 5, i + 1)
    plt.imshow(images[i], cmap='gray')
    plt.title(EMOTIONS[labels[i]])
    plt.axis('off')
plt.show()
# Out:
# Number of images: 64
# Shape of images array: (64, 48, 48)
# Number of labels: 64

# %%
datagen = ImageDataGenerator(
    rotation_range=10,
    zoom_range=0.1,
    width_shift_range=0.1,
    height_shift_range=0.1,
    horizontal_flip=True
)
datagen.fit(X_train)

# %%
model = models.Sequential([
    layers.Conv2D(64, (3, 3), activation='relu', input_shape=(IMG_SIZE, IMG_SIZE, 1)),
    layers.MaxPooling2D(2, 2),
    layers.Conv2D(128, (3, 3), activation='relu'),
    layers.MaxPooling2D(2, 2),
    layers.Conv2D(128, (3, 3), activation='relu'),
    layers.MaxPooling2D(2, 2),
    layers.Flatten(),
    layers.Dense(128, activation='relu'),
    layers.Dropout(0.5),  # Dropout layer to prevent overfitting
    layers.Dense(len(EMOTIONS), activation='softmax')
])

# Compile the model
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

model.summary()
# Out:
# C:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                      │ (None, 46, 46, 64)          │             640 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 23, 23, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_1 (Conv2D)                    │ (None, 21, 21, 128)         │          73,856 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_1 (MaxPooling2D)       │ (None, 10, 10, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_2 (Conv2D)                    │ (None, 8, 8, 128)           │         147,584 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_2 (MaxPooling2D)       │ (None, 4, 4, 128)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 2048)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 128)                 │         262,272 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 128)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 8)                   │           1,032 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 485,384 (1.85 MB)
#  Trainable params: 485,384 (1.85 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
history = model.fit(datagen.flow(X_train, y_train, batch_size=32), epochs=100, validation_data=(X_test, y_test))
# Out:
# Epoch 1/100
# C:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 3s 476ms/step - accuracy: 0.1180 - loss: 2.1260 - val_accuracy: 0.1538 - val_loss: 2.0909
# Epoch 2/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step - accuracy: 0.1228 - loss: 2.0818 - val_accuracy: 0.0769 - val_loss: 2.0760
# Epoch 3/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step - accuracy: 0.1527 - loss: 2.0655 - val_accuracy: 0.0769 - val_loss: 2.0548
# Epoch 4/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - accuracy: 0.1697 - loss: 2.0558 - val_accuracy: 0.0769 - val_loss: 2.0507
# Epoch 5/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step - accuracy: 0.0829 - loss: 2.0373 - val_accuracy: 0.2308 - val_loss: 2.0574
# Epoch 6/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step - accuracy: 0.1658 - loss: 2.0482 - val_accuracy: 0.2308 - val_loss: 2.0550
# Epoch 7/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 0.1540 - loss: 2.0484 - val_accuracy: 0.1538 - val_loss: 2.0491
# Epoch 8/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step - accuracy: 0.2577 - loss: 2.0034 - val_accuracy: 0.1538 - val_loss: 2.0458
# Epoch 9/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step - accuracy: 0.1834 - loss: 1.9813 - val_accuracy: 0.1538 - val_loss: 2.0420
# Epoch 10/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - accuracy: 0.2429 - loss: 1.9431 - val_accuracy: 0.2308 - val_loss: 1.9947
# Epoch 11/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - accuracy: 0.2577 - loss: 2.0082 - val_accuracy: 0.3077 - val_loss: 1.9142
# Epoch 12/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - accuracy: 0.4544 - loss: 1.8827 - val_accuracy: 0.3846 - val_loss: 1.8576
# Epoch 13/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - accuracy: 0.3472 - loss: 1.8954 - val_accuracy: 0.2308 - val_loss: 1.8162
# Epoch 14/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step - accuracy: 0.2883 - loss: 1.7714 - val_accuracy: 0.2308 - val_loss: 1.7768
# Epoch 15/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - accuracy: 0.3446 - loss: 1.8454 - val_accuracy: 0.3077 - val_loss: 1.6784
# Epoch 16/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - accuracy: 0.4022 - loss: 1.6673 - val_accuracy: 0.4615 - val_loss: 1.5216
# Epoch 17/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step - accuracy: 0.3932 - loss: 1.6753 - val_accuracy: 0.4615 - val_loss: 1.4108
# Epoch 18/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - accuracy: 0.3492 - loss: 1.5798 - val_accuracy: 0.4615 - val_loss: 1.2961
# Epoch 19/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step - accuracy: 0.4716 - loss: 1.5156 - val_accuracy: 0.6154 - val_loss: 1.1838
# Epoch 20/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - accuracy: 0.5022 - loss: 1.5160 - val_accuracy: 0.6923 - val_loss: 1.0885
# Epoch 21/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - accuracy: 0.4830 - loss: 1.5404 - val_accuracy: 0.6154 - val_loss: 1.0476
# Epoch 22/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step - accuracy: 0.6072 - loss: 1.2958 - val_accuracy: 0.7692 - val_loss: 1.0283
# Epoch 23/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - accuracy: 0.6632 - loss: 1.1870 - val_accuracy: 0.7692 - val_loss: 0.9179
# Epoch 24/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - accuracy: 0.5927 - loss: 1.0872 - val_accuracy: 0.9231 - val_loss: 0.7551
# Epoch 25/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - accuracy: 0.6501 - loss: 1.0166 - val_accuracy: 0.8462 - val_loss: 0.6476
# Epoch 26/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - accuracy: 0.6528 - loss: 1.0065 - val_accuracy: 0.6923 - val_loss: 0.6290
# Epoch 27/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - accuracy: 0.6605 - loss: 0.9789 - val_accuracy: 0.7692 - val_loss: 0.5979
# Epoch 28/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - accuracy: 0.7075 - loss: 0.8980 - val_accuracy: 0.7692 - val_loss: 0.5487
# Epoch 29/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - accuracy: 0.7571 - loss: 0.7522 - val_accuracy: 1.0000 - val_loss: 0.4507
# Epoch 30/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - accuracy: 0.7571 - loss: 0.8404 - val_accuracy: 1.0000 - val_loss: 0.3687
# Epoch 31/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step - accuracy: 0.8166 - loss: 0.6709 - val_accuracy: 1.0000 - val_loss: 0.3253
# Epoch 32/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - accuracy: 0.8252 - loss: 0.6075 - val_accuracy: 1.0000 - val_loss: 0.2212
# Epoch 33/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - accuracy: 0.7337 - loss: 0.7960 - val_accuracy: 1.0000 - val_loss: 0.2099
# Epoch 34/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - accuracy: 0.7031 - loss: 0.7625 - val_accuracy: 1.0000 - val_loss: 0.2248
# Epoch 35/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - accuracy: 0.8407 - loss: 0.5867 - val_accuracy: 0.8462 - val_loss: 0.3352
# Epoch 36/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step - accuracy: 0.8166 - loss: 0.6331 - val_accuracy: 0.8462 - val_loss: 0.2801
# Epoch 37/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - accuracy: 0.7640 - loss: 0.4933 - val_accuracy: 1.0000 - val_loss: 0.1502
# Epoch 38/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - accuracy: 0.7206 - loss: 0.7204 - val_accuracy: 1.0000 - val_loss: 0.1307
# Epoch 39/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - accuracy: 0.8591 - loss: 0.4406 - val_accuracy: 1.0000 - val_loss: 0.1449
# Epoch 40/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - accuracy: 0.7102 - loss: 0.7434 - val_accuracy: 1.0000 - val_loss: 0.1564
# Epoch 41/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step - accuracy: 0.9432 - loss: 0.3170 - val_accuracy: 1.0000 - val_loss: 0.1160
# Epoch 42/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step - accuracy: 0.9171 - loss: 0.3131 - val_accuracy: 1.0000 - val_loss: 0.0943
# Epoch 43/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step - accuracy: 0.8865 - loss: 0.4749 - val_accuracy: 1.0000 - val_loss: 0.0866
# Epoch 44/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step - accuracy: 0.8910 - loss: 0.3625 - val_accuracy: 1.0000 - val_loss: 0.1101
# Epoch 45/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step - accuracy: 0.8303 - loss: 0.4369 - val_accuracy: 1.0000 - val_loss: 0.0572
# Epoch 46/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - accuracy: 0.8668 - loss: 0.3923 - val_accuracy: 1.0000 - val_loss: 0.0304
# Epoch 47/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step - accuracy: 0.7248 - loss: 0.7706 - val_accuracy: 1.0000 - val_loss: 0.0474
# Epoch 48/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - accuracy: 0.8799 - loss: 0.3335 - val_accuracy: 0.9231 - val_loss: 0.1795
# Epoch 49/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step - accuracy: 0.9126 - loss: 0.3627 - val_accuracy: 0.9231 - val_loss: 0.1672
# Epoch 50/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - accuracy: 0.9608 - loss: 0.3666 - val_accuracy: 0.9231 - val_loss: 0.1146
# Epoch 51/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step - accuracy: 0.9171 - loss: 0.3560 - val_accuracy: 1.0000 - val_loss: 0.0915
# Epoch 52/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - accuracy: 0.8329 - loss: 0.4169 - val_accuracy: 1.0000 - val_loss: 0.0617
# Epoch 53/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.9504 - loss: 0.2663 - val_accuracy: 1.0000 - val_loss: 0.0512
# Epoch 54/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - accuracy: 0.9869 - loss: 0.1525 - val_accuracy: 0.9231 - val_loss: 0.1385
# Epoch 55/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - accuracy: 0.8930 - loss: 0.3525 - val_accuracy: 1.0000 - val_loss: 0.1128
# Epoch 56/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - accuracy: 0.8799 - loss: 0.3513 - val_accuracy: 1.0000 - val_loss: 0.0231
# Epoch 57/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - accuracy: 0.9302 - loss: 0.1667 - val_accuracy: 1.0000 - val_loss: 0.0257
# Epoch 58/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - accuracy: 0.8930 - loss: 0.3156 - val_accuracy: 1.0000 - val_loss: 0.0810
# Epoch 59/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step - accuracy: 0.9302 - loss: 0.2908 - val_accuracy: 0.9231 - val_loss: 0.0741
# Epoch 60/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step - accuracy: 0.8865 - loss: 0.3040 - val_accuracy: 1.0000 - val_loss: 0.0174
# Epoch 61/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - accuracy: 0.8820 - loss: 0.3100 - val_accuracy: 1.0000 - val_loss: 0.0122
# Epoch 62/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - accuracy: 0.8276 - loss: 0.3420 - val_accuracy: 1.0000 - val_loss: 0.0129
# Epoch 63/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - accuracy: 0.9269 - loss: 0.3313 - val_accuracy: 1.0000 - val_loss: 0.0116
# Epoch 64/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - accuracy: 0.9007 - loss: 0.2652 - val_accuracy: 1.0000 - val_loss: 0.0173
# Epoch 65/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - accuracy: 0.8380 - loss: 0.4207 - val_accuracy: 1.0000 - val_loss: 0.0407
# Epoch 66/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - accuracy: 0.9694 - loss: 0.2920 - val_accuracy: 0.8462 - val_loss: 0.2284
# Epoch 67/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.8799 - loss: 0.3146 - val_accuracy: 0.7692 - val_loss: 0.2323
# Epoch 68/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step - accuracy: 0.8383 - loss: 0.5167 - val_accuracy: 0.9231 - val_loss: 0.1064
# Epoch 69/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step - accuracy: 0.9171 - loss: 0.3265 - val_accuracy: 0.9231 - val_loss: 0.0829
# Epoch 70/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - accuracy: 0.9346 - loss: 0.2163 - val_accuracy: 1.0000 - val_loss: 0.0551
# Epoch 71/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - accuracy: 0.8428 - loss: 0.2825 - val_accuracy: 1.0000 - val_loss: 0.0381
# Epoch 72/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - accuracy: 0.8951 - loss: 0.2986 - val_accuracy: 1.0000 - val_loss: 0.0224
# Epoch 73/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - accuracy: 0.9112 - loss: 0.3794 - val_accuracy: 1.0000 - val_loss: 0.0126
# Epoch 74/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step - accuracy: 0.9257 - loss: 0.2065 - val_accuracy: 1.0000 - val_loss: 0.0121
# Epoch 75/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - accuracy: 0.8903 - loss: 0.2257 - val_accuracy: 1.0000 - val_loss: 0.0546
# Epoch 76/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - accuracy: 0.9432 - loss: 0.2044 - val_accuracy: 1.0000 - val_loss: 0.0585
# Epoch 77/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - accuracy: 0.9269 - loss: 0.2142 - val_accuracy: 1.0000 - val_loss: 0.0648
# Epoch 78/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - accuracy: 0.9634 - loss: 0.1911 - val_accuracy: 1.0000 - val_loss: 0.0352
# Epoch 79/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - accuracy: 0.9530 - loss: 0.1716 - val_accuracy: 1.0000 - val_loss: 0.0095
# Epoch 80/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step - accuracy: 0.9171 - loss: 0.2309 - val_accuracy: 1.0000 - val_loss: 0.0179
# Epoch 81/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - accuracy: 0.9563 - loss: 0.2418 - val_accuracy: 1.0000 - val_loss: 0.0303
# Epoch 82/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step - accuracy: 0.9432 - loss: 0.1977 - val_accuracy: 1.0000 - val_loss: 0.0225
# Epoch 83/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step - accuracy: 0.9869 - loss: 0.1476 - val_accuracy: 1.0000 - val_loss: 0.0065
# Epoch 84/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step - accuracy: 0.9608 - loss: 0.1470 - val_accuracy: 1.0000 - val_loss: 0.0042
# Epoch 85/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - accuracy: 0.9242 - loss: 0.1969 - val_accuracy: 1.0000 - val_loss: 0.0044
# Epoch 86/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - accuracy: 0.9765 - loss: 0.1433 - val_accuracy: 1.0000 - val_loss: 0.0069
# Epoch 87/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - accuracy: 0.8779 - loss: 0.2941 - val_accuracy: 1.0000 - val_loss: 0.0035
# Epoch 88/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.9869 - loss: 0.1163 - val_accuracy: 1.0000 - val_loss: 0.0025
# Epoch 89/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - accuracy: 0.9165 - loss: 0.2398 - val_accuracy: 1.0000 - val_loss: 0.0035
# Epoch 90/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - accuracy: 0.9432 - loss: 0.1535 - val_accuracy: 1.0000 - val_loss: 0.0096
# Epoch 91/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step - accuracy: 0.8951 - loss: 0.3551 - val_accuracy: 0.8462 - val_loss: 0.2486
# Epoch 92/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - accuracy: 0.9869 - loss: 0.1127 - val_accuracy: 0.8462 - val_loss: 0.2742
# Epoch 93/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - accuracy: 0.9165 - loss: 0.2464 - val_accuracy: 1.0000 - val_loss: 0.0072
# Epoch 94/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - accuracy: 0.9739 - loss: 0.1258 - val_accuracy: 1.0000 - val_loss: 0.0028
# Epoch 95/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step - accuracy: 0.9563 - loss: 0.1545 - val_accuracy: 1.0000 - val_loss: 0.0031
# Epoch 96/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - accuracy: 1.0000 - loss: 0.0975 - val_accuracy: 1.0000 - val_loss: 0.0061
# Epoch 97/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step - accuracy: 0.9869 - loss: 0.1035 - val_accuracy: 1.0000 - val_loss: 0.0292
# Epoch 98/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - accuracy: 0.9765 - loss: 0.1196 - val_accuracy: 1.0000 - val_loss: 0.0564
# Epoch 99/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.9634 - loss: 0.1759 - val_accuracy: 1.0000 - val_loss: 0.0149
# Epoch 100/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.9608 - loss: 0.1475 - val_accuracy: 1.0000 - val_loss: 0.0035

# %%
tr_acc = history.history['accuracy']
tr_loss = history.history['loss']
val_acc = history.history['val_accuracy']
val_loss = history.history['val_loss']
index_loss = np.argmin(val_loss)
val_lowest = val_loss[index_loss]
index_acc = np.argmax(val_acc)
acc_highest = val_acc[index_acc]

Epochs = [i+1 for i in range(len(tr_acc))]
loss_label = f'best epoch= {str(index_loss + 1)}'
acc_label = f'best epoch= {str(index_acc + 1)}'

# Plot training history
plt.figure(figsize= (20, 8))
plt.style.use('fivethirtyeight')

plt.subplot(1, 2, 1)
plt.plot(Epochs, tr_loss, 'r', label= 'Training loss')
plt.plot(Epochs, val_loss, 'g', label= 'Validation loss')
plt.scatter(index_loss + 1, val_lowest, s= 150, c= 'blue', label= loss_label)
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(Epochs, tr_acc, 'r', label= 'Training Accuracy')
plt.plot(Epochs, val_acc, 'g', label= 'Validation Accuracy')
plt.scatter(index_acc + 1 , acc_highest, s= 150, c= 'blue', label= acc_label)
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.tight_layout
plt.show()

# %%
test_loss, test_accuracy = model.evaluate(X_test, y_test, verbose=2)

print(f"Test Loss: {test_loss}")
print(f"Test Accuracy: {test_accuracy}")
# Out:
# 1/1 - 0s - 84ms/step - accuracy: 1.0000 - loss: 0.0035
# Test Loss: 0.0034832379315048456
# Test Accuracy: 1.0

# %%
from sklearn.metrics import classification_report

# Make predictions on the test set
predictions = model.predict(X_test)
predicted_labels = np.argmax(predictions, axis=1)

# Print classification report
print(classification_report(y_test, predicted_labels, target_names=EMOTIONS))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 244ms/step
#               precision    recall  f1-score   support
#
#        Anger       1.00      1.00      1.00         2
#     Contempt       1.00      1.00      1.00         2
#      Disgust       1.00      1.00      1.00         1
#         Fear       1.00      1.00      1.00         1
#        Happy       1.00      1.00      1.00         1
#      Neutral       1.00      1.00      1.00         2
#          Sad       1.00      1.00      1.00         1
#    Surprised       1.00      1.00      1.00         3
#
#     accuracy                           1.00        13
#    macro avg       1.00      1.00      1.00        13
# weighted avg       1.00      1.00      1.00        13

# %%
predictions = model.predict(X_test)
predicted_labels = np.argmax(predictions, axis=1)

# Generate the confusion matrix
cm = confusion_matrix(y_test, predicted_labels)

# Plot the confusion matrix
plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=EMOTIONS, yticklabels=EMOTIONS)
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.title('Confusion Matrix')
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step

# %%
import matplotlib.pyplot as plt

# Make predictions on the test set
predictions = model.predict(X_test)
predicted_labels = np.argmax(predictions, axis=1)

# Function to display images with predicted and actual labels
def display_images(images, actual_labels, predicted_labels, emotions, num_images=10):
    plt.figure(figsize=(20, 10))
    for i in range(num_images):
        plt.subplot(2, 5, i + 1)
        # Since the images are grayscale, we reshape them to (48, 48)
        img = images[i].reshape(IMG_SIZE, IMG_SIZE)
        plt.imshow(img, cmap='gray')
        plt.title(f"Actual: {emotions[actual_labels[i]]}\nPredicted: {emotions[predicted_labels[i]]}")
        plt.axis('off')
    plt.show()

# Display the images with predicted and actual labels
display_images(X_test, y_test, predicted_labels, EMOTIONS)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step

# %%
import cv2
import time
import tkinter as tk
from tkinter import Label, Button
from PIL import Image, ImageTk
from tkinter import messagebox


# Load the face detection model
modelFile = "res10_300x300_ssd_iter_140000.caffemodel"
configFile = "deploy.prototxt"
net = cv2.dnn.readNetFromCaffe(configFile, modelFile)

# Initialize Tkinter window
root = tk.Tk()
root.title("Full Photo Capture")
root.geometry("600x500")

# Label to display the captured image
image_label = Label(root)
image_label.pack()

name = ""
def capture_photo():
    global name
    name = name_entry.get().strip()  # Get user input
    if not name:
        messagebox.showerror("Error", "Please enter a name before capturing.")
        return
    cap = cv2.VideoCapture(0)
    image_saved = False  # Prevent multiple image saves instantly

    while True:
        ret, frame = cap.read()
        if not ret:
            break

        h, w = frame.shape[:2]
        blob = cv2.dnn.blobFromImage(frame, 1.0, (300, 300), (104.0, 177.0, 123.0), swapRB=False, crop=False)
        net.setInput(blob)
        detections = net.forward()

        for i in range(detections.shape[2]):
            confidence = detections[0, 0, i, 2]

            if confidence > 0.5:
                box = detections[0, 0, i, 3:7] * np.array([w, h, w, h])
                (x, y, x1, y1) = box.astype("int")

                # Draw rectangle around face
                cv2.rectangle(frame, (x, y), (x1, y1), (0, 255, 0), 3)
                text = f"Confidence: {confidence:.2f}"
                cv2.putText(frame, text, (x, y-10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 2)

                # Capture and save the full frame (not just face)
                if not image_saved:
                    timestamp = int(time.time())  # Unique filename
                    image_path = f"{name}.jpg"
                    cv2.imwrite(image_path, frame)  # Save the full image
                    print(f"Full photo saved: {image_path}")
                    image_saved = True

                    # Convert captured photo to display in Tkinter
                    frame_rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
                    frame_pil = Image.fromarray(frame_rgb)
                    frame_pil = frame_pil.resize((300, 300))  # Resize for display
                    frame_tk = ImageTk.PhotoImage(frame_pil)

                    # Update label with captured photo
                    image_label.config(image=frame_tk)
                    image_label.image = frame_tk  # Prevent garbage collection

        cv2.imshow("Face Detection", frame)

        if cv2.waitKey(1) & 0xFF == ord('q') or image_saved:
            break

    cap.release()
    cv2.destroyAllWindows()
    root.destroy()


tk.Label(root, text="Enter Name:", font=("Arial", 14)).pack(pady=5)
name_entry = tk.Entry(root, font=("Arial", 14))
name_entry.pack(pady=5)

# Button to open the camera and capture the full photo
capture_button = Button(root, text="Capture Photo", command=capture_photo, font=("Arial", 14))
capture_button.pack(pady=20)


# Run the GUI
root.mainloop()

# %%
img_array = cv2.imread(f"{name}.jpg", cv2.IMREAD_GRAYSCALE)
# img_array = cv2.imread(f"images/2/Happy.jpg", cv2.IMREAD_GRAYSCALE)
img_array
img_resized = cv2.resize(img_array, (48, 48))
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[14], line 4
#       2 # img_array = cv2.imread(f"images/2/Happy.jpg", cv2.IMREAD_GRAYSCALE)
#       3 img_array
# ----> 4 img_resized = cv2.resize(img_array, (48, 48))
#
# error: OpenCV(4.11.0) D:\a\opencv-python\opencv-python\opencv\modules\imgproc\src\resize.cpp:4208: error: (-215:Assertion failed) !ssize.empty() in function 'cv::resize'

# %%
img_resized = img_resized.reshape(-1, IMG_SIZE, IMG_SIZE, 1)

# %%
predictions = model.predict(img_resized)
predictions

# %%
predicted_labels = np.argmax(predictions, axis=1)
predicted_labels

# %%
EMOTIONS[predicted_labels[0]]
