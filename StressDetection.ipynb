# %%
import numpy as np 
import pandas as pd

# %%
df = pd.read_csv('Student_Depression_Dataset_Updated_Refined_WorkPressure.csv')
df.head(10)
# Out:
#    id  Gender  Age           City Profession  Academic Pressure  \
# 0   2    Male   33  Visakhapatnam    Student                  5
# 1   8  Female   24      Bangalore    Student                  2
# 2  26    Male   31       Srinagar    Student                  3
# 3  30  Female   28       Varanasi    Student                  3
# 4  32  Female   25         Jaipur    Student                  4
# 5  33    Male   29           Pune    Student                  2
# 6  52    Male   30          Thane    Student                  3
# 7  56  Female   30        Chennai    Student                  2
# 8  59    Male   28         Nagpur    Student                  3
# 9  62    Male   31         Nashik    Student                  2
#
#    Work Pressure  CGPA  Study Satisfaction  Job Satisfaction  \
# 0           10.0  8.97                   2                 0
# 1            4.6  5.90                   5                 0
# 2            8.1  7.03                   5                 0
# 3           10.0  5.59                   2                 0
# 4            8.0  8.13                   3                 0
# 5            6.5  5.70                   3                 0
# 6            6.3  9.54                   4                 0
# 7            3.3  8.04                   4                 0
# 8           10.0  9.79                   1                 0
# 9            8.5  8.38                   3                 0
#
#       Sleep Duration Dietary Habits    Degree  \
# 0          5-6 hours        Healthy   B.Pharm
# 1          5-6 hours       Moderate       BSc
# 2  Less than 5 hours        Healthy        BA
# 3          7-8 hours       Moderate       BCA
# 4          5-6 hours       Moderate    M.Tech
# 5  Less than 5 hours        Healthy       PhD
# 6          7-8 hours        Healthy       BSc
# 7  Less than 5 hours      Unhealthy  Class 12
# 8          7-8 hours       Moderate      B.Ed
# 9  Less than 5 hours       Moderate       LLB
#
#   Have you ever had suicidal thoughts ?  Work/Study Hours  Financial Stress  \
# 0                                   Yes                 3               1.0
# 1                                    No                 3               2.0
# 2                                    No                 9               1.0
# 3                                   Yes                 4               5.0
# 4                                   Yes                 1               1.0
# 5                                    No                 4               1.0
# 6                                    No                 1               2.0
# 7                                    No                 0               1.0
# 8                                   Yes                12               3.0
# 9                                   Yes                 2               5.0
#
#   Family History of Mental Illness  Stress    Emotion
# 0                               No       1  Surprised
# 1                              Yes       0    Neutral
# 2                              Yes       0    Neutral
# 3                              Yes       1    Disgust
# 4                               No       0  Surprised
# 5                               No       0    Neutral
# 6                               No       0       Fear
# 7                              Yes       0  Surprised
# 8                               No       1       Fear
# 9                               No       1      Happy

# %%
df.shape
# Out:
# (27901, 19)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27901 entries, 0 to 27900
# Data columns (total 19 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   id                                     27901 non-null  int64
#  1   Gender                                 27901 non-null  object
#  2   Age                                    27901 non-null  int64
#  3   City                                   27901 non-null  object
#  4   Profession                             27901 non-null  object
#  5   Academic Pressure                      27901 non-null  int64
#  6   Work Pressure                          27901 non-null  float64
#  7   CGPA                                   27901 non-null  float64
#  8   Study Satisfaction                     27901 non-null  int64
#  9   Job Satisfaction                       27901 non-null  int64
#  10  Sleep Duration                         27901 non-null  object
#  11  Dietary Habits                         27901 non-null  object
#  12  Degree                                 27901 non-null  object
#  13  Have you ever had suicidal thoughts ?  27901 non-null  object
#  14  Work/Study Hours                       27901 non-null  int64
#  15  Financial Stress                       27898 non-null  float64
#  16  Family History of Mental Illness       27901 non-null  object
#  17  Stress                                 27901 non-null  int64
#  18  Emotion                                27901 non-null  object
# dtypes: float64(3), int64(7), object(9)
# memory usage: 4.0+ MB

# %%
for i in df.columns:
    print(i)
# Out:
# id
# Gender
# Age
# City
# Profession
# Academic Pressure
# Work Pressure
# CGPA
# Study Satisfaction
# Job Satisfaction
# Sleep Duration
# Dietary Habits
# Degree
# Have you ever had suicidal thoughts ?
# Work/Study Hours
# Financial Stress
# Family History of Mental Illness
# Stress
# Emotion

# %%
df=df[df['Age']<35.0]
df['Age'].value_counts()
# Out:
# Age
# 24    2258
# 20    2237
# 28    2133
# 29    1950
# 33    1893
# 25    1784
# 21    1726
# 23    1645
# 18    1587
# 19    1560
# 34    1468
# 27    1462
# 31    1427
# 32    1262
# 22    1160
# 26    1155
# 30    1145
# Name: count, dtype: int64

# %%
df['Academic Pressure'].value_counts() ##remove outliers
df=df[df['Academic Pressure']!=0.0]
df['Academic Pressure'].value_counts()
# Out:
# Academic Pressure
# 3    7451
# 5    6281
# 4    5151
# 1    4788
# 2    4174
# Name: count, dtype: int64

# %%
df=df[df['Study Satisfaction']!=0.0]
df['Study Satisfaction'].value_counts()
# Out:
# Study Satisfaction
# 4    6351
# 2    5831
# 3    5808
# 1    5440
# 5    4412
# Name: count, dtype: int64

# %%
df['Degree'].value_counts()
# Out:
# Degree
# Class 12    6060
# B.Ed        1865
# B.Com       1503
# B.Arch      1476
# BCA         1433
# MSc         1188
# B.Tech      1152
# MCA         1040
# M.Tech      1021
# BHM          924
# BSc          884
# M.Ed         819
# B.Pharm      810
# M.Com        731
# BBA          696
# MBBS         691
# LLB          670
# BE           613
# BA           600
# M.Pharm      581
# MD           570
# MBA          562
# MA           544
# PhD          517
# LLM          482
# MHM          191
# ME           184
# Others        35
# Name: count, dtype: int64

# %%
df=df[df['Dietary Habits']!='Others']
df['Dietary Habits'].value_counts()
# Out:
# Dietary Habits
# Unhealthy    10301
# Moderate      9892
# Healthy       7637
# Name: count, dtype: int64

# %%
df=df[df['Sleep Duration']!='Others']
df['Sleep Duration'].value_counts()
# Out:
# Sleep Duration
# Less than 5 hours    8290
# 7-8 hours            7329
# 5-6 hours            6161
# More than 8 hours    6032
# Name: count, dtype: int64

# %%
df=df.drop(['id'],axis=1)

# %%
df['Age'].astype('int')
# Out:
# 0        33
# 1        24
# 2        31
# 3        28
# 4        25
#          ..
# 27896    27
# 27897    27
# 27898    31
# 27899    18
# 27900    27
# Name: Age, Length: 27812, dtype: int64

# %%
columns = ['Financial Stress', 'Work/Study Hours', 'Job Satisfaction', 
           'Age', 'Academic Pressure', 'Work Pressure', 'CGPA', 'Study Satisfaction']
df[columns].hist(alpha=0.75, bins=10)
# Out:
# array([[<Axes: title={'center': 'Financial Stress'}>,
#         <Axes: title={'center': 'Work/Study Hours'}>,
#         <Axes: title={'center': 'Job Satisfaction'}>],
#        [<Axes: title={'center': 'Age'}>,
#         <Axes: title={'center': 'Academic Pressure'}>,
#         <Axes: title={'center': 'Work Pressure'}>],
#        [<Axes: title={'center': 'CGPA'}>,
#         <Axes: title={'center': 'Study Satisfaction'}>, <Axes: >]],
#       dtype=object)

# %%
graduated = ['B.Ed', 'B.Com', 'B.Arch', 'BCA', 'B.Tech', 'BHM', 'BSc', 'B.Pharm', 'BBA', 'BE', 'BA']
post_graduated = ['MSc', 'MCA', 'M.Tech', 'M.Ed', 'M.Com', 'MBBS', 'LLB', 'M.Pharm', 'MD', 'MBA', 'MA', 'PhD', 'LLM', 'MHM', 'ME']
high_school = ['Class 12', 'Others']


# Iterate over the 'Degree' column and update its values
df['Degree']=df['Degree'].replace(graduated,'graduated')
df['Degree']=df['Degree'].replace(post_graduated,'post-graduated')
df['Degree']=df['Degree'].replace(high_school,'high_school')

# %%
df.drop([ 'Job Satisfaction','City'], axis=1, inplace=True)

# %%
df.loc[df['Gender']=='Male','Gender']=1;
df.loc[df['Gender']=='Female','Gender']=0;

df.loc[df['Sleep Duration']=='Less than 5 hours','Sleep Duration']=3
df.loc[df['Sleep Duration']=='7-8 hours','Sleep Duration']=1
df.loc[df['Sleep Duration']=='5-6 hours','Sleep Duration']=2
df.loc[df['Sleep Duration']=='More than 8 hours','Sleep Duration']=0

df.loc[df['Dietary Habits']=='Unhealthy','Dietary Habits']=2
df.loc[df['Dietary Habits']=='Moderate','Dietary Habits']=1
df.loc[df['Dietary Habits']=='Healthy','Dietary Habits']=0

df.loc[df['Degree']=='graduated','Degree']=1
df.loc[df['Degree']=='post-graduated','Degree']=2
df.loc[df['Degree']=='high_school','Degree']=0

df.loc[df['Have you ever had suicidal thoughts ?']=='Yes','Have you ever had suicidal thoughts ?']=1
df.loc[df['Have you ever had suicidal thoughts ?']=='No','Have you ever had suicidal thoughts ?']=0

df.loc[df['Family History of Mental Illness']=='Yes','Family History of Mental Illness']=1
df.loc[df['Family History of Mental Illness']=='No','Family History of Mental Illness']=0

df.loc[df['Profession'] == 'Student','Profession']=1
df.loc[df['Profession'] != 'Student','Profession']=0

EMOTIONS = ['Anger', 'Contempt', 'Disgust', 'Fear', 'Happy', 'Neutral', 'Sad', 'Surprised']

# index = 0
for i in EMOTIONS:
    df.loc[df['Emotion'] == i,'Emotion'] = EMOTIONS.index(i)

df = df.dropna()

# %%
df.head()
# Out:
#   Gender  Age Profession  Academic Pressure  Work Pressure  CGPA  \
# 0      1   33          0                  5           10.0  8.97
# 1      0   24          0                  2            4.6  5.90
# 2      1   31          0                  3            8.1  7.03
# 3      0   28          0                  3           10.0  5.59
# 4      0   25          0                  4            8.0  8.13
#
#    Study Satisfaction Sleep Duration Dietary Habits Degree  \
# 0                   2              2              0      1
# 1                   5              2              1      1
# 2                   5              3              0      1
# 3                   2              1              1      1
# 4                   3              2              1      2
#
#   Have you ever had suicidal thoughts ?  Work/Study Hours  Financial Stress  \
# 0                                     1                 3               1.0
# 1                                     0                 3               2.0
# 2                                     0                 9               1.0
# 3                                     1                 4               5.0
# 4                                     1                 1               1.0
#
#   Family History of Mental Illness  Stress Emotion
# 0                                0       1       7
# 1                                1       0       5
# 2                                1       0       5
# 3                                1       1       2
# 4                                0       0       7

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
from sklearn.linear_model import LogisticRegression

# %%
y=df['Stress']
x=df.drop(['Stress'],axis=1)
x.shape
# Out:
# (27809, 15)

# %%
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=1)

# %% [markdown]
# # Logistic Regression

# %%
log_reg = LogisticRegression()
log_reg.fit(X_train, y_train)
log_reg_pred = log_reg.predict(X_test)

accuracy_score(y_test,log_reg_pred)*100
# Out:
# 85.79647608773823

# %% [markdown]
# # Decision Tree Classifier

# %% [markdown]
# ### max_depth = 50

# %%
from sklearn.tree import DecisionTreeClassifier

dt_classifier_50=DecisionTreeClassifier(max_depth=50,min_samples_split=50)
dt_classifier_50.fit(X_train,y_train)
dt_pred_50=dt_classifier_50.predict(X_test)
accuracy_score(y_test,dt_pred_50)*100
# Out:
# 85.4908306364617

# %% [markdown]
# ### max_depth = 80

# %%
dt_classifier_80=DecisionTreeClassifier(max_depth=80,min_samples_split=80)
dt_classifier_80.fit(X_train,y_train)
dt_pred_80=dt_classifier_80.predict(X_test)
accuracy_score(y_test,dt_pred_80)*100
# Out:
# 85.04135203164329

# %% [markdown]
# # Random Forest Classifier

# %%
from sklearn.ensemble import RandomForestClassifier


forest = RandomForestClassifier(random_state=20)


forest.fit(X_train,y_train)

forest_pred = forest.predict(X_test)
accuracy_score(y_test,forest_pred)*100
# Out:
# 86.76734987414599

# %% [markdown]
# # Support Vector Machine

# %%
from sklearn.svm import SVC

# %% [markdown]
# ### Linear

# %%
lin_svm = SVC(kernel='linear', C=2)
lin_svm.fit(X_train, y_train)
lin_svm_pred = lin_svm.predict(X_test)

accuracy_score(y_test,lin_svm_pred)*100
# Out:
# 85.40093491549801

# %% [markdown]
# ### Radial Basis Function

# %%
rbf_svm = SVC(kernel='rbf',C=2)
rbf_svm.fit(X_train, y_train)
rbf_svm_pred = rbf_svm.predict(X_test)

accuracy_score(y_test,rbf_svm_pred)*100
# Out:
# 86.17403811578569

# %% [markdown]
# ### Sigmoid Function

# %%
sgm_svm = SVC(kernel='sigmoid')
sgm_svm.fit(X_train, y_train)
sgm_svm_pred = sgm_svm.predict(X_test)

accuracy_score(y_test,sgm_svm_pred)*100
# Out:
# 57.22761596548004

# %% [markdown]
# ### Polynomial Kernal

# %%
poly_svm = SVC(kernel='poly')
poly_svm.fit(X_train, y_train)
poly_svm_pred = poly_svm.predict(X_test)

accuracy_score(y_test,poly_svm_pred)*100
# Out:
# 86.40776699029125

# %% [markdown]
# # Scores

# %%
from sklearn.metrics import confusion_matrix,classification_report
from sklearn import metrics
import matplotlib.pyplot as plt


def scores(y_test,y_pred):
    print(f'Accuracy Score {metrics.accuracy_score(y_test,y_pred)*100}')
    print(f'Precision Score {metrics.precision_score(y_test,y_pred)*100}')
    print(f'Sensitivity Score {metrics.recall_score(y_test,y_pred)*100}')
    print(f'Specificity Score {metrics.recall_score(y_test,y_pred,pos_label=0)*100}')
    print(f'F1 Score for  {metrics.f1_score(y_test,y_pred)*100}')

# %% [markdown]
# ### Logistic Regression

# %%
scores(y_test,log_reg_pred)
# Out:
# Accuracy Score 85.79647608773823
# Precision Score 86.01832692876145
# Sensitivity Score 90.17663464518128
# Specificity Score 79.74304068522484
# F1 Score for  88.04841149773071

# %%
print(classification_report(y_test,log_reg_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.85      0.80      0.82      2335
#            1       0.86      0.90      0.88      3227
#
#     accuracy                           0.86      5562
#    macro avg       0.86      0.85      0.85      5562
# weighted avg       0.86      0.86      0.86      5562

# %% [markdown]
# ### Decision Tree Classifier

# %% [markdown]
# #### max_depth 50

# %%
scores(y_test,dt_pred_50)
# Out:
# Accuracy Score 85.4908306364617
# Precision Score 86.71116504854369
# Sensitivity Score 88.5652308645801
# Specificity Score 81.24197002141328
# F1 Score for  87.62839184424345

# %%
print(classification_report(y_test,dt_pred_50))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.84      0.81      0.82      2335
#            1       0.87      0.89      0.88      3227
#
#     accuracy                           0.85      5562
#    macro avg       0.85      0.85      0.85      5562
# weighted avg       0.85      0.85      0.85      5562

# %% [markdown]
# #### max_depth 80

# %%
scores(y_test,dt_pred_80)
# Out:
# Accuracy Score 85.04135203164329
# Precision Score 86.14548747358889
# Sensitivity Score 88.44127672761078
# Specificity Score 80.34261241970022
# F1 Score for  87.2782874617737

# %%
print(classification_report(y_test,dt_pred_80))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.83      0.80      0.82      2335
#            1       0.86      0.88      0.87      3227
#
#     accuracy                           0.85      5562
#    macro avg       0.85      0.84      0.85      5562
# weighted avg       0.85      0.85      0.85      5562

# %% [markdown]
# ### Random Forest Classifier

# %%
scores(y_test,forest_pred)
# Out:
# Accuracy Score 86.76734987414599
# Precision Score 87.68532526475038
# Sensitivity Score 89.80477223427332
# Specificity Score 82.5695931477516
# F1 Score for  88.73239436619718

# %%
print(classification_report(y_test,forest_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.85      0.83      0.84      2335
#            1       0.88      0.90      0.89      3227
#
#     accuracy                           0.87      5562
#    macro avg       0.87      0.86      0.86      5562
# weighted avg       0.87      0.87      0.87      5562

# %% [markdown]
# ### Support vector machine

# %% [markdown]
# ##### Linear kernel

# %%
scores(y_test,lin_svm_pred)
# Out:
# Accuracy Score 85.40093491549801
# Precision Score 85.96961572832886
# Sensitivity Score 89.43290982336536
# Specificity Score 79.8286937901499
# F1 Score for  87.66707168894288

# %%
print(classification_report(y_test,lin_svm_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.85      0.80      0.82      2335
#            1       0.86      0.89      0.88      3227
#
#     accuracy                           0.85      5562
#    macro avg       0.85      0.85      0.85      5562
# weighted avg       0.85      0.85      0.85      5562

# %% [markdown]
# ##### sigmoid

# %%
scores(y_test,sgm_svm_pred)
# Out:
# Accuracy Score 57.22761596548004
# Precision Score 62.732732732732735
# Sensitivity Score 64.73504803222806
# Specificity Score 46.85224839400428
# F1 Score for  63.71816379441818

# %%
print(classification_report(y_test,sgm_svm_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.49      0.47      0.48      2335
#            1       0.63      0.65      0.64      3227
#
#     accuracy                           0.57      5562
#    macro avg       0.56      0.56      0.56      5562
# weighted avg       0.57      0.57      0.57      5562

# %% [markdown]
# ##### Radial Biasis

# %%
scores(y_test,rbf_svm_pred)
# Out:
# Accuracy Score 86.17403811578569
# Precision Score 86.16833431430253
# Sensitivity Score 90.73442826154323
# Specificity Score 79.87152034261243
# F1 Score for  88.39245283018869

# %%
print(classification_report(y_test,rbf_svm_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.86      0.80      0.83      2335
#            1       0.86      0.91      0.88      3227
#
#     accuracy                           0.86      5562
#    macro avg       0.86      0.85      0.86      5562
# weighted avg       0.86      0.86      0.86      5562

# %% [markdown]
# ##### Polynomial

# %%
scores(y_test,poly_svm_pred)
# Out:
# Accuracy Score 86.40776699029125
# Precision Score 85.98893096417129
# Sensitivity Score 91.47815308335916
# Specificity Score 79.40042826552462
# F1 Score for  88.64864864864866

# %%
print(classification_report(y_test,poly_svm_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.87      0.79      0.83      2335
#            1       0.86      0.91      0.89      3227
#
#     accuracy                           0.86      5562
#    macro avg       0.87      0.85      0.86      5562
# weighted avg       0.86      0.86      0.86      5562
